# %%
# Implementasi Closures dengan Syntactic Sugar
def outer(pesan):
    def inner():
        print(pesan)
    return inner

sapa = outer("Sakti kan ini closure")
sapa()  # Output: Sakti kan ini closure

# Implementasi Decorator
def timing_decorator(func):
    import time

    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"waktu eksekusi untuk {func.__name__}: {end_time - start_time} detik")
        return result

    return wrapper

@timing_decorator
def komputasi_brutal(n):
    # Misalkan ini adalah komputasi berat yang memakan waktu
    result = sum(range(n))
    return result

print(komputasi_brutal(10000))

# Implementasi Memoization
def memoize(func):
    cache = {}

    def memoized_func(n):
        if n not in cache:
            cache[n] = func(n)
        return cache[n]

    return memoized_func

@memoize
def fibonacci(n):
    if n <= 1:
        return n
    else:
        return fibonacci(n-1) + fibonacci(n-2)

print(fibonacci(10))  # Output: 55
# Out:
# Sakti kan ini closure
# waktu eksekusi untuk komputasi_brutal: 0.00032138824462890625 detik
# 49995000
# 55
